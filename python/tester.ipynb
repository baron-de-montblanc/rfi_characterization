# %%
from mapper import bg_subtract

clean, noise = bg_subtract()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/SSINS/lib/python3.13/site-packages/scipy/optimize/_minimize.py:1046, in _validate_bounds(bounds, x0, meth)
#    1045 try:
# -> 1046     bounds.lb = np.broadcast_to(bounds.lb, x0.shape)
#    1047     bounds.ub = np.broadcast_to(bounds.ub, x0.shape)
#
# File ~/miniconda3/envs/SSINS/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:410, in broadcast_to(array, shape, subok)
#     369 """Broadcast an array to a new shape.
#     370
#     371 Parameters
#    (...)    408        [1, 2, 3]])
#     409 """
# --> 410 return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~/miniconda3/envs/SSINS/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:349, in _broadcast_to(array, shape, subok, readonly)
#     348 extras = []
# --> 349 it = np.nditer(
# ...
